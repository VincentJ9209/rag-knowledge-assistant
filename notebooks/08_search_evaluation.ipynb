# %% [markdown]
# # Keyword Search Evaluation
#
# This thin notebook displays reproducible tuning and holdout results produced by `scripts/evaluate_search.py`.

# %%
from pathlib import Path
import csv

root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
results_path = root / 'data' / 'evaluation' / 'search_evaluation_results.csv'
with results_path.open(newline='', encoding='utf-8') as source:
    rows = list(csv.DictReader(source))

for row in rows:
    print(row)
